# %%
import pandas as pd

# %%
df = pd.read_csv('Indonesian_Food_Recipes.csv')
df.head(10)
# Out:
#                            Title  \
# 0               Ayam Woku Manado
# 1       Ayam goreng tulang lunak
# 2               Ayam cabai kawin
# 3                    Ayam Geprek
# 4                    Minyak Ayam
# 5                Nasi Bakar Ayam
# 6        Ayam Saus Hintalu Jaruk
# 7  Ayam saos teriyaki Lada Hitam
# 8                     Steak ayam
# 9    Ayam Saos Asam Manis Simple
#
#                                          Ingredients  \
# 0  1 Ekor Ayam Kampung (potong 12)--2 Buah Jeruk ...
# 1  1 kg ayam (dipotong sesuai selera jangan kecil...
# 2  1/4 kg ayam--3 buah cabai hijau besar--7 buah ...
# 3  250 gr daging ayam (saya pakai fillet)--Secuku...
# 4  400 gr kulit ayam & lemaknya--8 siung bawang p...
# 5  1 piring nasi--¹/⁴ fillet ayam, potong kotak, ...
# 6  1/2 Ekor ayam--2 Butir Hintalu Jaruk--1 Buah C...
# 7  Ayam bagian dada dan tulang--1 buah bawang bom...
# 8  300 gr dada ayam fillet--1 sdm air jeruk nipis...
# 9  1/4 kg Ayam bagian dada fillet (Potong dadu)--...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14945 entries, 0 to 14944
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Title                14945 non-null  object
#  1   Ingredients          14945 non-null  object
#  2   Steps                14945 non-null  object
#  3   Loves                14945 non-null  int64
#  4   URL                  14945 non-null  object
#  5   Category             14945 non-null  object
#  6   Title Cleaned        14925 non-null  object
#  7   Total Ingredients    14945 non-null  int64
#  8   Ingredients Cleaned  14945 non-null  object
#  9   Total Steps          14945 non-null  int64
# dtypes: int64(3), object(7)
# memory usage: 1.1+ MB

# %%
df = df.drop(columns=['Steps', 'Loves', 'URL', 'Category', 'Title Cleaned', 'Total Ingredients', 'Ingredients Cleaned', 'Total Steps'])
df.head()
# Out:
#                       Title                                        Ingredients
# 0          Ayam Woku Manado  1 Ekor Ayam Kampung (potong 12)--2 Buah Jeruk ...
# 1  Ayam goreng tulang lunak  1 kg ayam (dipotong sesuai selera jangan kecil...
# 2          Ayam cabai kawin  1/4 kg ayam--3 buah cabai hijau besar--7 buah ...
# 3               Ayam Geprek  250 gr daging ayam (saya pakai fillet)--Secuku...
# 4               Minyak Ayam  400 gr kulit ayam & lemaknya--8 siung bawang p...

# %%
print(df['Ingredients'].iloc[0])
# Out:
# 1 Ekor Ayam Kampung (potong 12)--2 Buah Jeruk Nipis--2 Sdm Garam--3 Ruas Kunyit--7 Bawang Merah--7 Bawang Putih--10 Cabe Merah--10 Cabe Rawit Merah (sesuai selera)--3 Butir Kemiri--2 Batang Sereh--2 Lembar Daun Salam--2 Ikat Daun Kemangi--Penyedap Rasa--1 1/2 Gelas Air--

# %%
df = df.iloc[:1000]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Title                1000 non-null   object
#  1   Ingredients          1000 non-null   object
#  2   Steps                1000 non-null   object
#  3   Loves                1000 non-null   int64
#  4   URL                  1000 non-null   object
#  5   Category             1000 non-null   object
#  6   Title Cleaned        1000 non-null   object
#  7   Total Ingredients    1000 non-null   int64
#  8   Ingredients Cleaned  1000 non-null   object
#  9   Total Steps          1000 non-null   int64
# dtypes: int64(3), object(7)
# memory usage: 78.3+ KB

# %%
df.to_csv('dataset_baru.csv', index=False)
